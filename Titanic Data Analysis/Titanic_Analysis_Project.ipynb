# %% [markdown]
# # Titanic_Data_Analysis_Project -----

# %% [markdown]
# #

# %% [markdown]
# ###  Read the csv file of Titanic---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("D://titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #  Data Cleaning Process---

# %% [markdown]
# ### Analysis the dataset Before cleaning :-

# %%
# Check number of rows and columns in dataset--
df.shape
# Out:
# (891, 12)

# %%
# Check Total Columns and rows--
df.size
# Out:
# 10692

# %%
# Check info of each and every columns and rows --
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# check the Stats of datasets--
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ###  Remove the null values from datasets  :-

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
# check the total null values---
pd.isnull(df).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# FILL MISSING VALUES OF AGES WITH MEAN
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# FILL MISSING VALUES OF Embarked with S
df['Embarked'].fillna(df['Embarked']=="S",inplace=True)

# %%
#   drop the all missing values from datasets--

df.dropna(axis=1,inplace=True)

# %%
#convert Age float value to int type
df['Age']=df['Age'].astype('int')

# %%
pd.isnull(df).sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Now check the number of rows and columns after droping the null values--
df.shape
# Out:
# (891, 11)

# %%
# Analysis on columns after cleaning the datasets--


df.isnull().sum()

# Now our datasets is properly cleaned--
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(4)
# memory usage: 73.2+ KB

# %% [markdown]
# ####   Rename the column Name--

# %%
df.rename(columns={'Sex':'Gender'},inplace=True)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name Gender  Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris   male   22      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %% [markdown]
# # EDA ---

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name Gender  Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris   male   22      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %% [markdown]
# #### Count the Total number of Passenger which r Survived and which r not survived ---

# %%
a=df.groupby('Survived')['PassengerId'].size()
a
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
a=df.groupby('Survived')['PassengerId'].size()

c= a.plot(kind='bar')
plt.title("Survived Vs Passengers")
plt.ylabel("Number of Passengeers")
for bars in c.containers :
    c.bar_label(bars)

# %% [markdown]
# ### count the total male and  female passenger travel in ship

# %%
a= df.groupby("Gender").size()
a
# Out:
# Gender
# female    314
# male      577
# dtype: int64

# %%
a= df.groupby("Gender").size()
b=a.plot(kind='barh')
plt.title("Passengers Vs Gender")

plt.xlabel(" Number of Passengers")
for bars in b.containers :
    b.bar_label(bars)

# %% [markdown]
# #### count the total male and  female passenger which r survived travel in ship

# %%
a= df.groupby("Gender")['Survived'].value_counts()
b= a.plot(kind='barh')
plt.ylabel(" Number of Passengers")
plt.title("Gender Vs Survived")
for bars in b.containers :
    b.bar_label(bars)

# %% [markdown]
# ####  Count total Survived according to the Pclass of ship

# %%
r= df.groupby("Pclass")['Survived'].value_counts()
b= r.plot(kind='barh')
plt.ylabel(" Number of Passengers")
plt.title("Gender Vs Survived")
for bars in b.containers :
    b.bar_label(bars)

# %% [markdown]
# ####    Embarked VS Fare :-

# %%
a= df.groupby(['Embarked'])['Fare'].max().sort_values( ascending = False)
a
# Out:
# Embarked
# C        512.3292
# S        263.0000
# Q         90.0000
# False     80.0000
# Name: Fare, dtype: float64

# %%
b=a.plot(kind='barh')
plt.title("Embarked Vs Fare")
plt.xlabel("Fare")

for bars in b.containers:
    b.bar_label(bars)

# %% [markdown]
# #### Find the total pasengers which r 'survived' and 'not survived' but they travel in 'Plcass'

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name Gender  Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris   male   22      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
a= df.groupby(['Survived','Gender'])['Pclass'].value_counts().sort_values( ascending = False)
a
# Out:
# Survived  Gender  Pclass
# 0         male    3         300
#                   2          91
# 1         female  1          91
# 0         male    1          77
#           female  3          72
# 1         female  3          72
#                   2          70
#           male    3          47
#                   1          45
#                   2          17
# 0         female  2           6
#                   1           3
# Name: Pclass, dtype: int64

# %%
a=pd.crosstab([df['Survived'],df['Pclass']],df['Gender'])
a
# Out:
# Gender           female  male
# Survived Pclass
# 0        1            3    77
#          2            6    91
#          3           72   300
# 1        1           91    45
#          2           70    17
#          3           72    47

# %%
b=a.plot(kind='barh')
plt.title("Survival According to Gender and Class")
plt.xlabel("Number of pasengers")

for bars in b.containers:
    b.bar_label(bars)

# %% [markdown]
# #### Finding the name of  of pasenger who survives most and travel in plcass

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name Gender  Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris   male   22      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
a= df.groupby(['Name','PassengerId','Survived','Gender'])['Pclass'].value_counts().sort_values( ascending = False)
a
# Out:
# Name                                     PassengerId  Survived  Gender  Pclass
# Abbing, Mr. Anthony                      846          0         male    3         1
# Nysveen, Mr. Johan Hansen                327          0         male    3         1
# Nicholson, Mr. Arthur Ernest             546          0         male    1         1
# Nicola-Yarred, Master. Elias             126          1         male    3         1
# Nicola-Yarred, Miss. Jamila              40           1         female  3         1
#                                                                                  ..
# Goodwin, Miss. Lillian Amy               72           0         female  3         1
# Goodwin, Mr. Charles Edward              684          0         male    3         1
# Goodwin, Mrs. Frederick (Augusta Tyler)  679          0         female  3         1
# Graham, Miss. Margaret Edith             888          1         female  1         1
# ...

# %%
# there are 45 passsengers----

r= df['Gender']== 'male'
s= df['Pclass']==1
t= df['Survived']==1
a=df[r & s & t].value_counts()
a.reset_index().head()
#a.size
# Out:
#    PassengerId  Survived  Pclass  \
# 0           24         1       1
# 1          600         1       1
# 2          608         1       1
# 3          622         1       1
# 4          631         1       1
#
#                                            Name Gender  Age  SibSp  Parch  \
# 0                  Sloper, Mr. William Thompson   male   28      0      0
# 1  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")   male   49      1      0
# 2                   Daniel, Mr. Robert Williams   male   27      0      0
# 3                  Kimball, Mr. Edwin Nelson Jr   male   42      1      0
# 4          Barkworth, Mr. Algernon Henry Wilson   male   80      0      0
#
#      Ticket     Fare Embarked  0
# 0    113788  35.5000        S  1
# 1  PC 17485  56.9292        C  1
# 2    113804  30.5000        S  1
# 3     11753  52.5542        S  1
# 4     27042  30.0000        S  1

# %% [markdown]
# #### passenger travel from which city

# %%
a=df['Embarked'].value_counts()
c=a.plot(kind='bar')
plt.title("Total Passengers Vs Embarked")
plt.xlabel("Embarked")
plt.ylabel("Number of Passengers")
for bars in c.containers:
    c.bar_label(bars)

# %%
a= df.groupby(['Survived','Gender'])['Embarked'].value_counts().sort_values( ascending = False)
a
# Out:
# Survived  Gender  Embarked
# 0         male    S           364
# 1         female  S           140
#           male    S            77
# 0         male    C            66
# 1         female  C            64
# 0         female  S            63
#           male    Q            38
# 1         male    C            29
#           female  Q            27
# 0         female  C             9
#                   Q             9
# 1         male    Q             3
#           female  False         2
# Name: Embarked, dtype: int64

# %%
c=a.plot(kind='barh')
plt.title("Survived Vs Gender-Embarked ")
plt.xlabel("Numbers of Passengers")

for bars in c.containers:
    c.bar_label(bars)

# %% [markdown]
# #### Total Survived Passengers According to the Embarked--

# %%
a= df.groupby(['Survived'])['Embarked'].value_counts().sort_values( ascending = False)
a
# Out:
# Survived  Embarked
# 0         S           427
# 1         S           217
#           C            93
# 0         C            75
#           Q            47
# 1         Q            30
#           False         2
# Name: Embarked, dtype: int64

# %%
c=a.plot(kind='barh')
plt.title("Embarked Vs Survived")
plt.xlabel("Numbers of Passengers")

for bars in c.containers:
    c.bar_label(bars)

# %% [markdown]
# # To find that Whcich Age passengers r mostly died and survived

# %%
# Most survived passengers by Age
a=df.groupby('Age')['Survived'].value_counts().sort_values(ascending=False).head(5)
c=a.plot(kind='barh')
plt.title("Survived Vs Ages")
plt.xlabel("Numbers of Passengers")

for bars in c.containers:
    c.bar_label(bars)

# %% [markdown]
# #### find the passenger who had paid highest Fares :-

# %%
df.sort_values('Fare',ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
#
#      Gender  Age  SibSp  Parch    Ticket      Fare Embarked
# 258  female   35      0      0  PC 17755  512.3292        C
# 737    male   35      0      0  PC 17755  512.3292        C
# 679    male   36      0      1  PC 17755  512.3292        C
# 88   female   23      3      2     19950  263.0000        S
# 27     male   19      3      2     19950  263.0000        S

# %%
# this pasenger has paid max fare 
df[df['Survived']== 1].sort_values('Fare', ascending=False)
df.max().reset_index()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20988\1346624197.py:3: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max().reset_index()
#          index                            0
# 0  PassengerId                          891
# 1     Survived                            1
# 2       Pclass                            3
# 3         Name  van Melkebeke, Mr. Philemon
# 4       Gender                         male
# 5          Age                           80
# 6        SibSp                            8
# 7        Parch                            6
# 8       Ticket                    WE/P 5735
# 9         Fare                     512.3292

# %%
# this pasenger has paid min fare 
df[df['Survived']== 1].sort_values('Fare', ascending=False)
df.min().reset_index()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20988\1117947548.py:3: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min().reset_index()
#          index                    0
# 0  PassengerId                    1
# 1     Survived                    0
# 2       Pclass                    1
# 3         Name  Abbing, Mr. Anthony
# 4       Gender               female
# 5          Age                    0
# 6        SibSp                    0
# 7        Parch                    0
# 8       Ticket               110152
# 9         Fare                  0.0

# %% [markdown]
# #### Find the total Fares , according to Survived  and not survived

# %%
a=df.groupby('Survived')['Fare'].sum()
a.sort_values(ascending=False)
# Out:
# Survived
# 1    16551.2294
# 0    12142.7199
# Name: Fare, dtype: float64

# %%
c=a.plot(kind='bar')
plt.ylabel("Fare")
plt.title("Fare Vs Survived")
for bars in c.containers:
    c.bar_label(bars)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name Gender  Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris   male   22      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %% [markdown]
# ### Find total fares According to plcass of class

# %%
a= df.groupby('Pclass')['Fare'].sum()
a
# Out:
# Pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: Fare, dtype: float64

# %%
c=a.plot(kind='bar')
plt.ylabel("Fare")
plt.title("Fare Vs Pclass")
for bars in c.containers:
    
    c.bar_label(bars)

# %% [markdown]
# ###  find total fares , according to pclass, Gender

# %%
a= df.groupby(['Pclass','Gender'])['Fare'].sum()
a
# Out:
# Pclass  Gender
# 1       female    9975.8250
#         male      8201.5875
# 2       female    1669.7292
#         male      2132.1125
# 3       female    2321.1086
#         male      4393.5865
# Name: Fare, dtype: float64

# %%
c=a.plot(kind='barh')
plt.ylabel("Pclass,Gender")
plt.title("Fare Vs   Pclass-Gender")
for bars in c.containers:
    c.bar_label(bars)

# %% [markdown]
# #### Find the total Fares , according to pclass , gender, survived,Embarked

# %%
a= df.groupby(['Pclass','Gender','Survived','Embarked'])['Fare'].sum()
c=a.plot(kind='barh')

plt.title("Total Fare by  Pclass-Gender-Survived-Embarked")
plt.xlabel("Total Fares")

for bars in c.containers:
    c.bar_label(bars)

# %% [markdown]
# #### Find the total Fares According to gender ,pclass , Survived

# %%
a= df.groupby(['Pclass','Gender','Survived',])['Fare'].sum()
a
# Out:
# Pclass  Gender  Survived
# 1       female  0            331.8125
#                 1           9644.0125
#         male    0           4842.9081
#                 1           3358.6794
# 2       female  0            109.5000
#                 1           1560.2292
#         male    0           1773.4958
#                 1            358.6167
# 3       female  0           1423.6627
#                 1            897.4459
#         male    0           3661.3408
#                 1            732.2457
# Name: Fare, dtype: float64

# %%
c=a.plot(kind='barh')

plt.title("Total Fare Vs Gender-Pclass-Survived")
for bars in c.containers:
    c.bar_label(bars)

# %% [markdown]
# ## Conclusion :-

# %% [markdown]
# ####     1)Moslty Female Passengers r Survived in Titanic Ship as compare to male Passengers
# ####    2)The female Passenger r survived which r travel from 'S' Embarked burt male passenger travel from same class r totaly died
# ####    3) Mostly '29' Age  Passengers r survived in titanic
# ####    4) Mostly in 3 pclass category passengers r died upto 372 in that mostly male upto 300 and female upto 72 r died
# ####    5) Mostly passenger   travel from in S Emarked
# ####    6) The Titanic Ship  Total Fare of Survival Passengers is Highly as compare to Non Survived Passengers
# ####    7) Pclass 1 fare is high in Titanic
# ####    8) Total Fare for Female passengers is highly upto 9975.83 as they r in Pclass 1

# %% [markdown]
# ## Insights :-

# %% [markdown]
# ####    1) Titanic Ship shoud not to Onbaord  Passengers of  the 'S' Embarked Destination Because Most of Passenger r Dies from that category embarked
# ####      2) Titanic ship should have to check 'S' Embarked Destination  "sea radar" so that Accident may not be happened At that time
# ####      3) Mostly Male Passengers r belong to the 'S' Destination Embarked as they r not survived in ship
